# %%
import pandas as pd

# %%
tags= pd.read_csv('tags.csv')
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags['tag']= tags['tag'].str.lower()

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     boxing story  1445715207
# 4       2    89774              mma  1445715200

# %%
tags.to_csv('tags_new.csv')

# %%
personality=pd.read_csv('personality-data.csv')

# %%
personality.head()
# Out:
#                              userid   openness   agreeableness  \
# 0  8e7cebf9a234c064b75016249f2ac65e        5.0             2.0
# 1  77c7d756a093150d4377720abeaeef76        7.0             4.0
# 2  b7e8a92987a530cc368719a0e60e26a3        4.0             3.0
# 3  92561f21446e017dd6b68b94b23ad5b7        5.5             5.5
# 4  030001ac2145a938b07e686a35a2d638        5.5             5.5
#
#     emotional_stability   conscientiousness   extraversion  assigned metric  \
# 0                   3.0                 2.5            6.5      serendipity
# 1                   6.0                 5.5            4.0              all
# 2                   4.5                 2.0            2.5      serendipity
# 3                   4.0                 4.5            4.0       popularity
# 4                   3.5                 4.5            2.5       popularity
#
#    assigned condition   movie_1   predicted_rating_1  ...   movie_9  \
# ...

# %%
table1= pd.DataFrame(columns=['userid','openness','agreeableness','emotional_stability','conscientiousness','extraversion'])

# %%
cols=[ x.strip() for x in list(personality.columns)]

# %%
personality.columns=cols

# %%
table1[['userid','openness','agreeableness','emotional_stability','conscientiousness','extraversion']]=personality[['userid','openness','agreeableness','emotional_stability','conscientiousness','extraversion']]

# %%
table1.dtypes
# Out:
# userid                  object
# openness               float64
# agreeableness          float64
# emotional_stability    float64
# conscientiousness      float64
# extraversion           float64
# dtype: object

# %%
table1.to_csv('personality.csv')
